# %%
import pandas as pd
import ast

# %%
data = pd.read_csv('cleaned.csv')
data.head()
# Out:
#                                       name  \
# 0  air fryer lemon garlic parmesan chicken
# 1                        air fryer s’mores
# 2                     air fryer baked yams
# 3     lemon garlic butter chicken spiedini
# 4         air fryer grilled pimento cheese
#
#                                          ingredients  \
# 0  [{'quantity': '1 1/2', 'unit': 'pounds', 'name...
# 1  [{'quantity': '1', 'unit': 'sleeve', 'name': '...
# 2  [{'quantity': '1', 'unit': None, 'name': 'yam'...
# 3  [{'quantity': '1/2', 'unit': 'cup', 'name': 'e...
# 4  [{'quantity': '4', 'unit': 'slices', 'name': '...
#
#                                                steps  calories carbs protein  \
# 0  Gather all ingredients.. Preheat an air fryer ...     365.0    8g     46g
# 1  Preheat an air fryer to 380 degrees F (193 deg...     143.0   20g      2g
# 2  Preheat an air fryer to 400 degrees F (200 deg...     283.0   62g      3g
# ...

# %%
# Create a new DataFrame with only 'ingredients' and 'link' columns
ingredients_df = data[['ingredients', 'link']]
ingredients_df.head()
# Out:
#                                          ingredients  \
# 0  [{'quantity': '1 1/2', 'unit': 'pounds', 'name...
# 1  [{'quantity': '1', 'unit': 'sleeve', 'name': '...
# 2  [{'quantity': '1', 'unit': None, 'name': 'yam'...
# 3  [{'quantity': '1/2', 'unit': 'cup', 'name': 'e...
# 4  [{'quantity': '4', 'unit': 'slices', 'name': '...
#
#                                                 link
# 0  https://www.allrecipes.com/air-fryer-lemon-gar...
# 1  https://www.allrecipes.com/air-fryer-s-mores-r...
# 2  https://www.allrecipes.com/air-fryer-baked-yam...
# 3  https://www.allrecipes.com/lemon-garlic-butter...
# 4  https://www.allrecipes.com/air-fryer-grilled-p...

# %%
print(ingredients_df.iloc[0]['ingredients'])
# Out:
# [{'quantity': '1 1/2', 'unit': 'pounds', 'name': 'skinless boneless chicken thighs', 'quantity_in_grams': 453.59}, {'quantity': '3', 'unit': 'cloves', 'name': 'garlic, minced', 'quantity_in_grams': 15.0}, {'quantity': '1', 'unit': 'teaspoon', 'name': 'lemon zest', 'quantity_in_grams': 5.0}, {'quantity': '1', 'unit': 'teaspoon', 'name': 'paprika', 'quantity_in_grams': 5.0}, {'quantity': '1', 'unit': 'teaspoon', 'name': 'dried oregano', 'quantity_in_grams': 5.0}, {'quantity': '1/2', 'unit': 'teaspoon', 'name': 'salt', 'quantity_in_grams': 5.0}, {'quantity': '1/4', 'unit': 'teaspoon', 'name': 'crushed red pepper', 'quantity_in_grams': 5.0}, {'quantity': '1/2', 'unit': 'cup', 'name': 'grated parmesan cheese', 'quantity_in_grams': 240.0}, {'quantity': '1/4', 'unit': 'cup', 'name': 'panko bread crumbs', 'quantity_in_grams': 240.0}, {'quantity': None, 'unit': None, 'name': 'cooking spray', 'quantity_in_grams': 0}]
