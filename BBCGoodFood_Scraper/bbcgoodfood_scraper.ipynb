# %%
#import libraries
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import csv
from urllib.request import Request
from urllib.error import URLError
from urllib.parse import urlparse
from urllib.parse import urljoin
import os
import requests

# %% [markdown]
# ## Getting Article Data (Scraping)

# %%
def get_recipe_name(soup):
    name = soup.find('h1', class_='heading-1') 
    return name.text.strip() if name else "No recipe name found"


def get_ingredients(soup):
    ingredients_list = []

    # Regex pattern for capturing quantity and unit
    quantity_unit_pattern = re.compile(r"(\d+(?:\.\d+)?|½|¼|⅓|⅔)?\s*(\w+)?\s*(.*)")

    # Find all the list items in the ingredients list
    ingredient_items = soup.find_all('li', class_='ingredients-list__item')

    for item in ingredient_items:
        text = item.get_text(separator=" ", strip=True)
        quantity = None
        unit = None
        ingredient = None
        item_note = None

        # Match the quantity and unit
        match = quantity_unit_pattern.match(text)
        if match:
            quantity = match.group(1)  # Capture the numeric value or fraction
            unit = match.group(2)     # Capture the unit
            text = match.group(3).strip()  # Remaining text after quantity and unit

        # Extract item notes (if present)
        note_div = item.find('div', class_='ingredients-list__item-note')
        if note_div:
            item_note = note_div.get_text(strip=True)

        # Remove item note from the ingredient name if it exists
        if item_note and text.endswith(item_note):
            ingredient = text.replace(item_note, '').strip()
        else:
            ingredient = text

        # Append the parsed ingredient with the appropriate structure
        ingredients_list.append({
            'name': ingredient,  # Main ingredient name
            'quantity': quantity,      # Extracted quantity
            'unit': unit,              # Extracted unit
            'item_note': item_note     # Any additional notes
        })

    return ingredients_list




    
def get_steps(soup):
    # Find the method steps container
    steps_list = soup.find('ul', class_='method-steps__list')
    if not steps_list:
        print("Steps list not found!")
        return

    # Parse each step
    steps = []
    step_counter = 1
    for item in steps_list.find_all('li', class_='method-steps__list-item'):
        step_heading = f"Step {step_counter}: "
        step_text = item.find('div', class_='editor-content').get_text(strip=True)
        steps.append(step_heading + step_text)
        step_counter += 1
    
    return steps


def get_nutrition_data(soup):
    """
    Extract nutrition data from a BeautifulSoup object.
    Returns a dictionary of nutrition information.
    """
    nutrition_dict = {}
    
    # Locate the nutrition section
    nutrition_list = soup.find('ul', class_='nutrition-list')
    if not nutrition_list:
        return nutrition_dict  # Return empty if no nutrition data is found
    
    # Iterate through each nutrition item
    for item in nutrition_list.find_all('li', class_='nutrition-list__item'):
        key_element = item.find('span', class_='fw-600 mr-1')  # Bold text for the nutrient name
        if not key_element:
            continue
        key = key_element.get_text(strip=True)
        
        # Extract the value following the nutrient name
        value = item.get_text(strip=True).replace(key, '')  # Remove the key part
        nutrition_dict[key] = value
    
    return nutrition_dict

def get_serving_data(soup):
    serving = None
    # Find all <div> elements with the class "icon-with-text__children"
    dd_elements = soup.find_all('div', class_='icon-with-text__children')
    if len(dd_elements) >= 3:
        serving_text = dd_elements[2].text.strip()
        # Match the serving range (e.g., "4 – 6") or a single number
        serving_range_match = re.search(r'(\d+)\s*–\s*(\d+)', serving_text)
        if serving_range_match:
            serving = int(serving_range_match.group(1))
        else:
            serving = int(''.join(filter(str.isdigit, serving_text)))

    return serving

def get_image_url(soup):
    image_url = None
    media_div = soup.find('div', class_='post-header__image-container')
    if media_div:
        picture_tag = media_div.find('picture')
        if picture_tag:
            img_tag = picture_tag.find('img')
            if img_tag and 'src' in img_tag.attrs:
                image_url = img_tag['src']
    return image_url

# %%
#head of getting recipe
def fetch_recipe_data(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    req = Request(url, headers=headers)
    response = urlopen(req)
    html = response.read().decode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')
    
   
    name= get_recipe_name(soup),
    ingredient= get_ingredients(soup),
    steps= get_steps(soup),
    nutrition=get_nutrition_data(soup),
    link=url
    serve=get_serving_data(soup)
    image_url=get_image_url(soup)
    
    
    return name,ingredient,steps,nutrition,link,serve,image_url

# %% [markdown]
# ## Going Trough Recomendation (Crawling)

# %%
# Extract recommended article URLs from a given article (crawl)
def get_recommended_recipes(url):
    response = urlopen(url)
    soup_obj = BeautifulSoup(response, 'html.parser')

    # Initialize the list to store the recommended recipe URLs
    recommended_recipes = []

    # Update the selector to find links with the class for recipes (adjust as per your HTML structure)
    for a_tag in soup_obj.find_all('a', class_='link d-block', href=True):
        recommended_url = a_tag['href']
        
        # Convert relative URLs to absolute URLs
        full_url = urljoin(url, recommended_url)
        recommended_recipes.append(full_url)
    
    return recommended_recipes

# %%
#get the new recipes from the recomended section
def process_recommended_recipes(recipe_url, processed_urls, recipe_data, max_depth, step, base_url):
    if step < max_depth:
        try:
            recommended_recipes = get_recommended_recipes(recipe_url)
            print(f"From {recipe_url}, getting {len(recommended_recipes)} recommended links at depth {step}.")

            for rec_url in recommended_recipes:
                full_rec_url = urljoin(base_url, rec_url)
                if full_rec_url in processed_urls:
                    continue

                processed_urls.add(full_rec_url)
                print(f"Processing recommended article: {full_rec_url}")
                rectitle, recingredients, recstep, recnutrition, reclink,reserve,reimage_url = fetch_recipe_data(full_rec_url)
                recipe_data.append((rectitle, recingredients, recstep, recnutrition, reclink,reserve,reimage_url))

                process_recommended_recipes(full_rec_url, processed_urls, recipe_data, max_depth, step + 1, base_url)
        except Exception as e:
            print(f"Error processing {recipe_url}: {e}")
    else:
        return

# %% [markdown]
# ## Implementation

# %%
# #main pipeline
# # def scrape_main_page(max_depth=10, max_recipes=5):
# def scrape_main_page(max_depth=0, max_recipes=1):
#     start_url = 'https://www.bbcgoodfood.com/recipes/collection/all-low-calorie'
#     base_url = 'https://www.bbcgoodfood.com'
#     response = urlopen(start_url)
#     soup = BeautifulSoup(response, 'html.parser')

#     urls = []  # to hold each collection
#     dynamic_list_div = soup.find('div', class_='dynamic-list dynamic-list--multi-column')
#     if dynamic_list_div:
#         list_items = dynamic_list_div.find_all('li', class_='dynamic-list__list-item')
#         for item in list_items:
#             link_tag = item.find('a', href=True)
#             if link_tag:
#                 urls.append(urljoin(base_url, link_tag['href']))

#     recipes_data = []
#     processed_urls = set()
#     recipe_count = 0  # Counter to limit to 5 recipes

#     for url in urls:  # loop through collections
#         response = urlopen(url)
#         soup = BeautifulSoup(response, 'html.parser')

#         recipes_section = soup.find('div', class_='post__content')
#         if recipes_section:
#             recipes = recipes_section.find_all('article', class_='card text-align-left card--horizontal card--inline')
#             print(f"Scraping the main page: Found {len(recipes)} recipes.")
            
#             for recipe in recipes:
#                 if recipe_count >= max_recipes:  # Stop once we have 5 recipes
#                     break

#                 title_tag = recipe.find('div', class_='card__section card__content')
#                 recipe_url = title_tag.find('a')['href']
#                 full_recipe_url = urljoin(base_url, recipe_url)

#                 if full_recipe_url in processed_urls:
#                     continue
                
#                 processed_urls.add(full_recipe_url)
#                 print(f"Processing article: {full_recipe_url}")
#                 title, ingredients, step, nutrition, link, serve, image_url = fetch_recipe_data(full_recipe_url)
#                 recipes_data.append((title, ingredients, step, nutrition, link, serve, image_url))
                
#                 process_recommended_recipes(full_recipe_url, processed_urls, recipes_data, max_depth, 0, base_url)

#                 recipe_count += 1
#             if recipe_count >= max_recipes:
#                 break

#     return recipes_data


#main pipeline
def scrape_main_page(max_depth=10):
    start_url = 'https://www.bbcgoodfood.com/recipes/collection/all-low-calorie'
    base_url = 'https://www.bbcgoodfood.com'
    response = urlopen(start_url)
    soup = BeautifulSoup(response, 'html.parser')

    urls = []#to hold each collection
    dynamic_list_div = soup.find('div', class_='dynamic-list dynamic-list--multi-column')
    if dynamic_list_div:
        list_items = dynamic_list_div.find_all('li', class_='dynamic-list__list-item')
        for item in list_items:
            link_tag = item.find('a', href=True)
            if link_tag:
                urls.append(urljoin(base_url, link_tag['href']))

    recipes_data = []
    processed_urls = set()

    for url in urls:#loop trough collections
        response = urlopen(url)
        soup = BeautifulSoup(response, 'html.parser')

        recipes_section = soup.find('div', class_='post__content')
        if recipes_section:
            recipes = recipes_section.find_all('article', class_='card text-align-left card--horizontal card--inline')
            print(f"Scraping the main page: Found {len(recipes)} recipes.")
            
            for recipe in recipes:
                title_tag = recipe.find('div', class_='card__section card__content')
                recipe_url = title_tag.find('a')['href']
                full_recipe_url = urljoin(base_url, recipe_url)

                if full_recipe_url in processed_urls:
                    continue
                
                processed_urls.add(full_recipe_url)
                print(f"Processing article: {full_recipe_url}")
                title, ingredients, step, nutrition, link, serve, image_url = fetch_recipe_data(full_recipe_url)
                recipes_data.append((title, ingredients, step, nutrition, link, serve, image_url))
                
                process_recommended_recipes(full_recipe_url, processed_urls, recipes_data, max_depth, 0, base_url)

    return recipes_data

# %%
# Write the data to a CSV file
def write_to_csv(data):
    # Clear the file by opening it in write mode and immediately closing it
    with open('BBCGoodFoodScrap.csv', mode='w', newline='', encoding='utf-8') as file:
        file.truncate()  # Clear content, if any

    # Open again to write data
    with open('BBCGoodFoodScrap.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        # Include the 'News Link' column in the header
        writer.writerow(['title', 'ingredients', 'step', 'nutrition', 'link', 'serve','image_url'])
        for row in data:
            # Check if any attribute in the row is None or empty
            if all(row):
                writer.writerow(row)

# %%
# Main function
def main():
    article_data = scrape_main_page()
    write_to_csv(article_data)

main() #call the main
# Out:
# Scraping the main page: Found 24 recipes.
# Processing article: https://www.bbcgoodfood.com/recipes/salsa-verde-baked-eggs
# From https://www.bbcgoodfood.com/recipes/salsa-verde-baked-eggs, getting 4 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/smoky-tomato-gazpacho
# From https://www.bbcgoodfood.com/recipes/smoky-tomato-gazpacho, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.buysubscriptions.com/print/good-food-magazine-subscription?promo=GFBS125&utm_medium=brandsite&utm_source=goodfood.com&utm_campaign=trial_GFBS125&utm_content=footer-widget&style=brand
# Steps list not found!
# From https://www.buysubscriptions.com/print/good-food-magazine-subscription?promo=GFBS125&utm_medium=brandsite&utm_source=goodfood.com&utm_campaign=trial_GFBS125&utm_content=footer-widget&style=brand, getting 0 recommended links at depth 2.
# Processing recommended article: https://immediate.onelink.me/OQap?af_web_dp=https%3A%2F%2Fwww.bbcgoodfood.com%2Fget-bbc-good-food-app&af_xp=custom&pid=website&c=footer_widget&is_retargeting=true
# Steps list not found!
# From https://immediate.onelink.me/OQap?af_web_dp=https%3A%2F%2Fwww.bbcgoodfood.com%2Fget-bbc-good-food-app&af_xp=custom&pid=website&c=footer_widget&is_retargeting=true, getting 2 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sausage-fennel-orecchiette
# From https://www.bbcgoodfood.com/recipes/sausage-fennel-orecchiette, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/roasted-cod-with-zingy-beetroot-salad
# From https://www.bbcgoodfood.com/recipes/roasted-cod-with-zingy-beetroot-salad, getting 4 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/tomato-soup-hummus-crispbreads
# From https://www.bbcgoodfood.com/recipes/tomato-soup-hummus-crispbreads, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/puy-lentils-with-seared-salmon
# From https://www.bbcgoodfood.com/recipes/puy-lentils-with-seared-salmon, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/puy-lentil-salad-with-beetroot-walnuts
# From https://www.bbcgoodfood.com/recipes/puy-lentil-salad-with-beetroot-walnuts, getting 5 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/winter-breakfast-hash
# From https://www.bbcgoodfood.com/recipes/winter-breakfast-hash, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/black-forest-breakfast-bowl
# From https://www.bbcgoodfood.com/recipes/black-forest-breakfast-bowl, getting 4 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cinnamon-porridge-with-baked-bananas
# From https://www.bbcgoodfood.com/recipes/cinnamon-porridge-with-baked-bananas, getting 4 recommended links at depth 5.
# Processing article: https://www.bbcgoodfood.com/recipes/baked-tomato-mozzarella-orzo
# From https://www.bbcgoodfood.com/recipes/baked-tomato-mozzarella-orzo, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/scampi-po-boys
# From https://www.bbcgoodfood.com/recipes/scampi-po-boys, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cauliflower-soup-fancy-chorizo-topping
# From https://www.bbcgoodfood.com/recipes/cauliflower-soup-fancy-chorizo-topping, getting 5 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/roasted-aubergine-chilli-peanut-dressing
# From https://www.bbcgoodfood.com/recipes/roasted-aubergine-chilli-peanut-dressing, getting 5 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/honey-soy-chicken-thighs-sesame-broccoli
# From https://www.bbcgoodfood.com/recipes/honey-soy-chicken-thighs-sesame-broccoli, getting 5 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sausage-kale-gnocchi-one-pot
# From https://www.bbcgoodfood.com/recipes/sausage-kale-gnocchi-one-pot, getting 5 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/salmon-sweet-potato-coriander-fishcakes-tahini-dressing
# From https://www.bbcgoodfood.com/recipes/salmon-sweet-potato-coriander-fishcakes-tahini-dressing, getting 5 recommended links at depth 3.
# Processing article: https://www.bbcgoodfood.com/recipes/healthy-tikka-masala
# From https://www.bbcgoodfood.com/recipes/healthy-tikka-masala, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/swedish-meatballs
# From https://www.bbcgoodfood.com/recipes/swedish-meatballs, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/squash-pesto-pasta
# From https://www.bbcgoodfood.com/recipes/squash-pesto-pasta, getting 5 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/prawn-fried-rice
# From https://www.bbcgoodfood.com/recipes/prawn-fried-rice, getting 5 recommended links at depth 3.
# Processing article: https://www.bbcgoodfood.com/recipes/carrot-biriyani
# From https://www.bbcgoodfood.com/recipes/carrot-biriyani, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chicken-tikka-masala-naans
# From https://www.bbcgoodfood.com/recipes/chicken-tikka-masala-naans, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/prosciutto-kale-butter-bean-stew
# From https://www.bbcgoodfood.com/recipes/prosciutto-kale-butter-bean-stew, getting 5 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/mustardy-salmon-beetroot-lentils
# From https://www.bbcgoodfood.com/recipes/mustardy-salmon-beetroot-lentils, getting 5 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sprout-black-pudding-apple-rostis
# From https://www.bbcgoodfood.com/recipes/sprout-black-pudding-apple-rostis, getting 5 recommended links at depth 4.
# Processing article: https://www.bbcgoodfood.com/recipes/sweet-potato-cauliflower-lentil-bowl
# From https://www.bbcgoodfood.com/recipes/sweet-potato-cauliflower-lentil-bowl, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lentil-sweet-potato-curry
# From https://www.bbcgoodfood.com/recipes/lentil-sweet-potato-curry, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/seeded-flatbreads
# From https://www.bbcgoodfood.com/recipes/seeded-flatbreads, getting 4 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/butternut-harissa-hummus
# From https://www.bbcgoodfood.com/recipes/butternut-harissa-hummus, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/smoked-salmon-taramasalata
# From https://www.bbcgoodfood.com/recipes/smoked-salmon-taramasalata, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/olive-bread-swirls
# From https://www.bbcgoodfood.com/recipes/olive-bread-swirls, getting 2 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/smoked-salmon-carbonara
# From https://www.bbcgoodfood.com/recipes/smoked-salmon-carbonara, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/garlic-bread-toasts
# From https://www.bbcgoodfood.com/recipes/garlic-bread-toasts, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/broad-bean-bruschetta
# From https://www.bbcgoodfood.com/recipes/broad-bean-bruschetta, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/rustic-bread
# From https://www.bbcgoodfood.com/recipes/rustic-bread, getting 2 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/zesty-pomegranate-rice
# From https://www.bbcgoodfood.com/recipes/zesty-pomegranate-rice, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/moroccan-style-chicken-carrot-orange-salad
# From https://www.bbcgoodfood.com/recipes/moroccan-style-chicken-carrot-orange-salad, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lemon-roasted-new-potatoes
# From https://www.bbcgoodfood.com/recipes/lemon-roasted-new-potatoes, getting 2 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/superhealthy-slaw
# From https://www.bbcgoodfood.com/recipes/superhealthy-slaw, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crisp-chicken-burgers-lemon-mayo
# From https://www.bbcgoodfood.com/recipes/crisp-chicken-burgers-lemon-mayo, getting 2 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/pumpkin-falafel-pockets
# From https://www.bbcgoodfood.com/recipes/pumpkin-falafel-pockets, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/halloween-pumpkin-cake
# From https://www.bbcgoodfood.com/recipes/halloween-pumpkin-cake, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/wizards-hat-pasties
# From https://www.bbcgoodfood.com/recipes/wizards-hat-pasties, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cheesy-bonfire-bread
# From https://www.bbcgoodfood.com/recipes/cheesy-bonfire-bread, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/winter-cannellini-bean-soup
# From https://www.bbcgoodfood.com/recipes/winter-cannellini-bean-soup, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lamb-en-croute-redcurrant-sauce
# From https://www.bbcgoodfood.com/recipes/lamb-en-croute-redcurrant-sauce, getting 4 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/berry-semifreddo-warm-chocolate-sauce
# From https://www.bbcgoodfood.com/recipes/berry-semifreddo-warm-chocolate-sauce, getting 3 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cauliflower-tempura
# From https://www.bbcgoodfood.com/recipes/cauliflower-tempura, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/aioli
# From https://www.bbcgoodfood.com/recipes/aioli, getting 3 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/thai-fried-prawn-pineapple-rice
# From https://www.bbcgoodfood.com/recipes/thai-fried-prawn-pineapple-rice, getting 2 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/tasty-turkey-meatballs
# From https://www.bbcgoodfood.com/recipes/tasty-turkey-meatballs, getting 3 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chilli-green-salad
# From https://www.bbcgoodfood.com/recipes/chilli-green-salad, getting 2 recommended links at depth 1.
# Processing article: https://www.bbcgoodfood.com/recipes/mapo-tofu
# From https://www.bbcgoodfood.com/recipes/mapo-tofu, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/steak-soy-ginger-butter
# From https://www.bbcgoodfood.com/recipes/steak-soy-ginger-butter, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/general-tsos-chicken
# From https://www.bbcgoodfood.com/recipes/general-tsos-chicken, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crisp-chinese-pork
# From https://www.bbcgoodfood.com/recipes/crisp-chinese-pork, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chinese-style-kale
# From https://www.bbcgoodfood.com/recipes/chinese-style-kale, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/peking-style-chicken
# From https://www.bbcgoodfood.com/recipes/peking-style-chicken, getting 2 recommended links at depth 4.
# Processing article: https://www.bbcgoodfood.com/recipes/veggie-yaki-udon
# From https://www.bbcgoodfood.com/recipes/veggie-yaki-udon, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/pork-souvlaki
# From https://www.bbcgoodfood.com/recipes/pork-souvlaki, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/jerk-style-chicken-pilaf
# From https://www.bbcgoodfood.com/recipes/jerk-style-chicken-pilaf, getting 5 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/fish-chip-traybake
# From https://www.bbcgoodfood.com/recipes/fish-chip-traybake, getting 5 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chipotle-chicken-slaw
# From https://www.bbcgoodfood.com/recipes/chipotle-chicken-slaw, getting 5 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sweet-sour-tofu
# From https://www.bbcgoodfood.com/recipes/sweet-sour-tofu, getting 5 recommended links at depth 3.
# Processing article: https://www.bbcgoodfood.com/recipes/summer-fish-stew
# From https://www.bbcgoodfood.com/recipes/summer-fish-stew, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/smoky-butter-beans-greens
# From https://www.bbcgoodfood.com/recipes/smoky-butter-beans-greens, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/tropical-fruits-lemongrass-syrup
# From https://www.bbcgoodfood.com/recipes/tropical-fruits-lemongrass-syrup, getting 2 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lemon-cod-basil-bean-mash
# From https://www.bbcgoodfood.com/recipes/lemon-cod-basil-bean-mash, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/potato-salad-sweet-onion-dressing
# From https://www.bbcgoodfood.com/recipes/potato-salad-sweet-onion-dressing, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/horseradish-butter-steaks
# From https://www.bbcgoodfood.com/recipes/horseradish-butter-steaks, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/flavoured-butters
# From https://www.bbcgoodfood.com/recipes/flavoured-butters, getting 5 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crunchy-baked-mussels
# From https://www.bbcgoodfood.com/recipes/crunchy-baked-mussels, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/salmon-noodle-wraps
# From https://www.bbcgoodfood.com/recipes/salmon-noodle-wraps, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/beer-battered-pollock-bites
# From https://www.bbcgoodfood.com/recipes/beer-battered-pollock-bites, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/oven-roasted-chips
# From https://www.bbcgoodfood.com/recipes/oven-roasted-chips, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/herby-fish-fingers
# From https://www.bbcgoodfood.com/recipes/herby-fish-fingers, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/quick-braised-lettuce-peas
# From https://www.bbcgoodfood.com/recipes/quick-braised-lettuce-peas, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/mediterranean-salmon-fillet
# From https://www.bbcgoodfood.com/recipes/mediterranean-salmon-fillet, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cherry-tomatoes
# From https://www.bbcgoodfood.com/recipes/cherry-tomatoes, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/griddled-swordfish-pineapple-chilli-salsa
# From https://www.bbcgoodfood.com/recipes/griddled-swordfish-pineapple-chilli-salsa, getting 2 recommended links at depth 5.
# Processing article: https://www.bbcgoodfood.com/recipes/creamy-tomato-courgetti
# From https://www.bbcgoodfood.com/recipes/creamy-tomato-courgetti, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/squished-tomato-pasta-sauce
# From https://www.bbcgoodfood.com/recipes/squished-tomato-pasta-sauce, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cheesy-garlic-bread
# From https://www.bbcgoodfood.com/recipes/cheesy-garlic-bread, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chilli-con-carne-recipe
# From https://www.bbcgoodfood.com/recipes/chilli-con-carne-recipe, getting 5 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/classic-guacamole
# From https://www.bbcgoodfood.com/recipes/classic-guacamole, getting 5 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/mexican-seafood-cocktail
# From https://www.bbcgoodfood.com/recipes/mexican-seafood-cocktail, getting 5 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/barbacoa-marinated-lamb-cutlets
# From https://www.bbcgoodfood.com/recipes/barbacoa-marinated-lamb-cutlets, getting 4 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/mezcalita-verde-cocktail
# From https://www.bbcgoodfood.com/recipes/mezcalita-verde-cocktail, getting 5 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cauliflower-rice
# From https://www.bbcgoodfood.com/recipes/cauliflower-rice, getting 5 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/home-style-pork-curry-cauliflower-rice
# From https://www.bbcgoodfood.com/recipes/home-style-pork-curry-cauliflower-rice, getting 5 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/grilled-flaky-naans
# From https://www.bbcgoodfood.com/recipes/grilled-flaky-naans, getting 4 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/indian-rice-salad-chicken
# From https://www.bbcgoodfood.com/recipes/indian-rice-salad-chicken, getting 5 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/tomato-cucumber-raita
# From https://www.bbcgoodfood.com/recipes/tomato-cucumber-raita, getting 4 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/low-fat-chicken-biryani
# From https://www.bbcgoodfood.com/recipes/low-fat-chicken-biryani, getting 4 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/carrot-cumin-salad
# Processing recommended article: https://www.bbcgoodfood.com/recipes/pumpkin-curry-chickpeas
# From https://www.bbcgoodfood.com/recipes/pumpkin-curry-chickpeas, getting 2 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/poppadums-lime-coriander-dip
# From https://www.bbcgoodfood.com/recipes/poppadums-lime-coriander-dip, getting 2 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/marvellous-mangoes
# From https://www.bbcgoodfood.com/recipes/marvellous-mangoes, getting 2 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/curried-chickpeas
# From https://www.bbcgoodfood.com/recipes/curried-chickpeas, getting 3 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/parsnip-pancakes-honey-mustard-dressing
# From https://www.bbcgoodfood.com/recipes/parsnip-pancakes-honey-mustard-dressing, getting 3 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/herb-spice-paneer-fritters
# From https://www.bbcgoodfood.com/recipes/herb-spice-paneer-fritters, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/fruity-lamb-tagine
# From https://www.bbcgoodfood.com/recipes/fruity-lamb-tagine, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/harissa-couscous
# From https://www.bbcgoodfood.com/recipes/harissa-couscous, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lamb-tagine-dates-sweet-potatoes
# From https://www.bbcgoodfood.com/recipes/lamb-tagine-dates-sweet-potatoes, getting 2 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/tomato-courgette-stew
# From https://www.bbcgoodfood.com/recipes/tomato-courgette-stew, getting 4 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/citrus-spiked-sea-bass
# From https://www.bbcgoodfood.com/recipes/citrus-spiked-sea-bass, getting 4 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/barbecued-fennel-black-olive-dressing
# From https://www.bbcgoodfood.com/recipes/barbecued-fennel-black-olive-dressing, getting 4 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/provencal-pork-skewers
# From https://www.bbcgoodfood.com/recipes/provencal-pork-skewers, getting 2 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/bulgur-wheat-carrots-hazelnuts
# From https://www.bbcgoodfood.com/recipes/bulgur-wheat-carrots-hazelnuts, getting 4 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/harissa-chicken-chickpea-salad
# From https://www.bbcgoodfood.com/recipes/harissa-chicken-chickpea-salad, getting 3 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/broccoli-garlic-chilli-breadcrumbs
# Processing recommended article: https://www.bbcgoodfood.com/recipes/moroccan-meatball-tagine-lemon-olives
# From https://www.bbcgoodfood.com/recipes/moroccan-meatball-tagine-lemon-olives, getting 4 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/tangy-couscous-salad
# Processing recommended article: https://www.bbcgoodfood.com/recipes/raspberry-rose-trifles
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sweet-potato-salad
# From https://www.bbcgoodfood.com/recipes/sweet-potato-salad, getting 4 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/moroccan-roasted-veg-tahini-dressing
# From https://www.bbcgoodfood.com/recipes/moroccan-roasted-veg-tahini-dressing, getting 4 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/harissa-chicken-traybake-0
# From https://www.bbcgoodfood.com/recipes/harissa-chicken-traybake-0, getting 4 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/speedy-moroccan-meatballs
# Processing recommended article: https://www.bbcgoodfood.com/recipes/vegetable-couscous-chickpeas-preserved-lemons
# Processing recommended article: https://www.bbcgoodfood.com/recipes/harissa-0
# From https://www.bbcgoodfood.com/recipes/harissa-0, getting 3 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/duck-apricot-pine-nut-pastilla
# From https://www.bbcgoodfood.com/recipes/duck-apricot-pine-nut-pastilla, getting 4 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/moroccan-tagine
# From https://www.bbcgoodfood.com/recipes/moroccan-tagine, getting 2 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/confit-duck
# From https://www.bbcgoodfood.com/recipes/confit-duck, getting 2 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/barbecued-saddle-lamb-lemon-rosemary
# From https://www.bbcgoodfood.com/recipes/barbecued-saddle-lamb-lemon-rosemary, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/taleggio-potato-parcels
# From https://www.bbcgoodfood.com/recipes/taleggio-potato-parcels, getting 3 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chocolate-mousse
# From https://www.bbcgoodfood.com/recipes/chocolate-mousse, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/trout-tomato-sauce
# From https://www.bbcgoodfood.com/recipes/trout-tomato-sauce, getting 5 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/foccaccia-rolls
# From https://www.bbcgoodfood.com/recipes/foccaccia-rolls, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/easy-caponata-0
# From https://www.bbcgoodfood.com/recipes/easy-caponata-0, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/artichoke-olive-dip
# From https://www.bbcgoodfood.com/recipes/artichoke-olive-dip, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crunchy-new-potatoes
# From https://www.bbcgoodfood.com/recipes/crunchy-new-potatoes, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/beef-salad-caper-parsley-dressing
# From https://www.bbcgoodfood.com/recipes/beef-salad-caper-parsley-dressing, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/shortbread-recipe
# From https://www.bbcgoodfood.com/recipes/shortbread-recipe, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/gooey-chocolate-cherry-cookies
# From https://www.bbcgoodfood.com/recipes/gooey-chocolate-cherry-cookies, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/jammy-coconut-mallows
# From https://www.bbcgoodfood.com/recipes/jammy-coconut-mallows, getting 4 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/fruit-oat-seed-bars
# From https://www.bbcgoodfood.com/recipes/fruit-oat-seed-bars, getting 3 recommended links at depth 5.
# Processing article: https://www.bbcgoodfood.com/recipes/courgette-pea-pesto-soup
# From https://www.bbcgoodfood.com/recipes/courgette-pea-pesto-soup, getting 4 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/brown-loaf
# From https://www.bbcgoodfood.com/recipes/brown-loaf, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/garlic-prosciutto-plait
# From https://www.bbcgoodfood.com/recipes/garlic-prosciutto-plait, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/classic-apple-chutney
# From https://www.bbcgoodfood.com/recipes/classic-apple-chutney, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/roast-pork-apples-cider-vinegar-rosemary
# From https://www.bbcgoodfood.com/recipes/roast-pork-apples-cider-vinegar-rosemary, getting 2 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cheese-caramelised-onion-coburg
# From https://www.bbcgoodfood.com/recipes/cheese-caramelised-onion-coburg, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crunchy-courgette-pickle
# From https://www.bbcgoodfood.com/recipes/crunchy-courgette-pickle, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cheeseburger-chips
# From https://www.bbcgoodfood.com/recipes/cheeseburger-chips, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/homemade-tomato-sauce
# From https://www.bbcgoodfood.com/recipes/homemade-tomato-sauce, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/golden-beer-battered-fish-chips
# From https://www.bbcgoodfood.com/recipes/golden-beer-battered-fish-chips, getting 4 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/watercress-mayonnaise
# From https://www.bbcgoodfood.com/recipes/watercress-mayonnaise, getting 2 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/basil-rosemary-chive-flowerpot
# From https://www.bbcgoodfood.com/recipes/basil-rosemary-chive-flowerpot, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/red-onion-rosemary-focaccia
# From https://www.bbcgoodfood.com/recipes/red-onion-rosemary-focaccia, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/classic-white-loaf
# From https://www.bbcgoodfood.com/recipes/classic-white-loaf, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/ham-tomato-stromboli
# From https://www.bbcgoodfood.com/recipes/ham-tomato-stromboli, getting 3 recommended links at depth 3.
# Processing article: https://www.bbcgoodfood.com/recipes/vegan-chilli
# From https://www.bbcgoodfood.com/recipes/vegan-chilli, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/easy-vegan-burgers
# From https://www.bbcgoodfood.com/recipes/easy-vegan-burgers, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lemony-potato-salad
# From https://www.bbcgoodfood.com/recipes/lemony-potato-salad, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/indian-spiced-barbecued-lamb
# From https://www.bbcgoodfood.com/recipes/indian-spiced-barbecued-lamb, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/smoky-aubergine-dip-barbecued-poppadums
# From https://www.bbcgoodfood.com/recipes/smoky-aubergine-dip-barbecued-poppadums, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/hot-dressed-sweet-potato-fennel-feta-parcels
# From https://www.bbcgoodfood.com/recipes/hot-dressed-sweet-potato-fennel-feta-parcels, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/carrot-sesame-burgers
# From https://www.bbcgoodfood.com/recipes/carrot-sesame-burgers, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chunky-oven-chips
# From https://www.bbcgoodfood.com/recipes/chunky-oven-chips, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/gordons-mix-match-steak
# From https://www.bbcgoodfood.com/recipes/gordons-mix-match-steak, getting 5 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/bois-boudrin
# From https://www.bbcgoodfood.com/recipes/bois-boudrin, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/shallot-red-wine-sauce
# From https://www.bbcgoodfood.com/recipes/shallot-red-wine-sauce, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/vegan-banana-peanut-butter-cupcakes
# From https://www.bbcgoodfood.com/recipes/vegan-banana-peanut-butter-cupcakes, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/miso-glazed-tofu-steaks-beansprout-salad-egg-strands
# From https://www.bbcgoodfood.com/recipes/miso-glazed-tofu-steaks-beansprout-salad-egg-strands, getting 4 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/korean-rice-pot
# From https://www.bbcgoodfood.com/recipes/korean-rice-pot, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/prawn-spring-roll-wraps
# From https://www.bbcgoodfood.com/recipes/prawn-spring-roll-wraps, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sticky-chinese-wings-cucumber
# From https://www.bbcgoodfood.com/recipes/sticky-chinese-wings-cucumber, getting 2 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lychee-passion-fruit-panna-cottas
# From https://www.bbcgoodfood.com/recipes/lychee-passion-fruit-panna-cottas, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/italian-sausage-chestnut-pasta
# From https://www.bbcgoodfood.com/recipes/italian-sausage-chestnut-pasta, getting 4 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/tomato-passata
# From https://www.bbcgoodfood.com/recipes/tomato-passata, getting 4 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/veggie-lasagne
# From https://www.bbcgoodfood.com/recipes/veggie-lasagne, getting 4 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/winter-crunch-salad
# From https://www.bbcgoodfood.com/recipes/winter-crunch-salad, getting 2 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/raw-lemon-cheesecake
# From https://www.bbcgoodfood.com/recipes/raw-lemon-cheesecake, getting 4 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lemon-sorbet
# From https://www.bbcgoodfood.com/recipes/lemon-sorbet, getting 5 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crispy-thyme-chicken-mushroom-sauce
# From https://www.bbcgoodfood.com/recipes/crispy-thyme-chicken-mushroom-sauce, getting 2 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/avocado-panzanella
# From https://www.bbcgoodfood.com/recipes/avocado-panzanella, getting 4 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/prawn-lime-noodles
# Processing recommended article: https://www.bbcgoodfood.com/recipes/griddled-tuna-bean-tomato-salad
# Processing recommended article: https://www.bbcgoodfood.com/recipes/red-berry-coulis
# From https://www.bbcgoodfood.com/recipes/red-berry-coulis, getting 4 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/peach-red-berry-ice-cream-cake
# From https://www.bbcgoodfood.com/recipes/peach-red-berry-ice-cream-cake, getting 5 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/green-gazpacho
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sticky-citrus-mustard-glazed-salmon
# Processing recommended article: https://www.bbcgoodfood.com/recipes/ultimate-vanilla-ice-cream
# From https://www.bbcgoodfood.com/recipes/ultimate-vanilla-ice-cream, getting 3 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/italian-cookies-ice-cream
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chicken-parmigiana
# From https://www.bbcgoodfood.com/recipes/chicken-parmigiana, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/prosecco-chocolate-salami
# From https://www.bbcgoodfood.com/recipes/prosecco-chocolate-salami, getting 4 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crab-linguine-chilli-parsley
# From https://www.bbcgoodfood.com/recipes/crab-linguine-chilli-parsley, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/coffee-semifreddo
# From https://www.bbcgoodfood.com/recipes/coffee-semifreddo, getting 3 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/macadamia-cranberry-american-cookies
# From https://www.bbcgoodfood.com/recipes/macadamia-cranberry-american-cookies, getting 3 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/raspberry-bakewell-cake
# From https://www.bbcgoodfood.com/recipes/raspberry-bakewell-cake, getting 3 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/classic-scones-jam-clotted-cream
# Processing recommended article: https://www.bbcgoodfood.com/recipes/affogato-al-caffe-vanilla-ice-cream-coffee
# From https://www.bbcgoodfood.com/recipes/affogato-al-caffe-vanilla-ice-cream-coffee, getting 4 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chocolate-pistachio-nougat-semifreddo
# From https://www.bbcgoodfood.com/recipes/chocolate-pistachio-nougat-semifreddo, getting 4 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/pistachio-cupcakes
# From https://www.bbcgoodfood.com/recipes/pistachio-cupcakes, getting 2 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/best-ever-tiramisu
# From https://www.bbcgoodfood.com/recipes/best-ever-tiramisu, getting 5 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/panforte
# From https://www.bbcgoodfood.com/recipes/panforte, getting 5 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/panettone
# Processing recommended article: https://www.bbcgoodfood.com/recipes/spiced-arancello
# Processing recommended article: https://www.bbcgoodfood.com/recipes/irish-cream
# Processing recommended article: https://www.bbcgoodfood.com/recipes/hazelnut-gelato-rich-chocolate-sauce
# From https://www.bbcgoodfood.com/recipes/hazelnut-gelato-rich-chocolate-sauce, getting 3 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/coconut-tuiles
# From https://www.bbcgoodfood.com/recipes/coconut-tuiles, getting 3 recommended links at depth 8.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/caramelised-pineapple-compotes
# From https://www.bbcgoodfood.com/recipes/caramelised-pineapple-compotes, getting 4 recommended links at depth 9.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/frosted-coriander-sprigs
# Processing recommended article: https://www.bbcgoodfood.com/recipes/vegan-rhubarb-custard-bake
# From https://www.bbcgoodfood.com/recipes/vegan-rhubarb-custard-bake, getting 4 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/vegan-tomato-mushroom-pancakes
# From https://www.bbcgoodfood.com/recipes/vegan-tomato-mushroom-pancakes, getting 2 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/vegetable-vegan-biriyani-carrot-salad
# From https://www.bbcgoodfood.com/recipes/vegetable-vegan-biriyani-carrot-salad, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/orange-coconut-salad
# From https://www.bbcgoodfood.com/recipes/orange-coconut-salad, getting 4 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/creamy-chicken-mango-curry
# From https://www.bbcgoodfood.com/recipes/creamy-chicken-mango-curry, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/indian-cucumber-salad
# From https://www.bbcgoodfood.com/recipes/indian-cucumber-salad, getting 4 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/curried-flatbread
# From https://www.bbcgoodfood.com/recipes/curried-flatbread, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/flatbread
# From https://www.bbcgoodfood.com/recipes/flatbread, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/no-fry-thai-curry
# From https://www.bbcgoodfood.com/recipes/no-fry-thai-curry, getting 2 recommended links at depth 4.
# Processing article: https://www.bbcgoodfood.com/recipes/avocado-black-bean-eggs
# From https://www.bbcgoodfood.com/recipes/avocado-black-bean-eggs, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/healthy-salad-nicoise
# From https://www.bbcgoodfood.com/recipes/healthy-salad-nicoise, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/mediterranean-sardine-salad
# From https://www.bbcgoodfood.com/recipes/mediterranean-sardine-salad, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/spiced-baked-figs-ginger-mascarpone
# From https://www.bbcgoodfood.com/recipes/spiced-baked-figs-ginger-mascarpone, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/goats-cheese-garlic-linguine-crisp-pancetta
# From https://www.bbcgoodfood.com/recipes/goats-cheese-garlic-linguine-crisp-pancetta, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/zingy-courgette-spinach-salad
# From https://www.bbcgoodfood.com/recipes/zingy-courgette-spinach-salad, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/ultimate-makeover-chicken-caesar-salad
# From https://www.bbcgoodfood.com/recipes/ultimate-makeover-chicken-caesar-salad, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/ultimate-makeover-new-york-cheesecake
# From https://www.bbcgoodfood.com/recipes/ultimate-makeover-new-york-cheesecake, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/ultimate-fish-cakes
# From https://www.bbcgoodfood.com/recipes/ultimate-fish-cakes, getting 4 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/fennel-watercress-pine-nut-salad
# From https://www.bbcgoodfood.com/recipes/fennel-watercress-pine-nut-salad, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/oven-baked-porcini-thyme-risotto
# From https://www.bbcgoodfood.com/recipes/oven-baked-porcini-thyme-risotto, getting 4 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/broken-biscotti-ice-cream-hot-mocha
# From https://www.bbcgoodfood.com/recipes/broken-biscotti-ice-cream-hot-mocha, getting 3 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cod-tomato-traybake
# From https://www.bbcgoodfood.com/recipes/cod-tomato-traybake, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/red-onion-gruyere-rosemary-fougasse
# From https://www.bbcgoodfood.com/recipes/red-onion-gruyere-rosemary-fougasse, getting 2 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/healthy-egg-chips
# From https://www.bbcgoodfood.com/recipes/healthy-egg-chips, getting 2 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/healthy-coleslaw
# From https://www.bbcgoodfood.com/recipes/healthy-coleslaw, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/ready-go-wraps
# From https://www.bbcgoodfood.com/recipes/ready-go-wraps, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sticky-popcorn-pots
# From https://www.bbcgoodfood.com/recipes/sticky-popcorn-pots, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/smoothie-jellies-ice-cream
# From https://www.bbcgoodfood.com/recipes/smoothie-jellies-ice-cream, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cheese-fruit-sticks
# Error processing https://www.bbcgoodfood.com/recipes/smoothie-jellies-ice-cream: invalid literal for int() with base 10: ''
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sausage-roll-twists-tomato-dip
# From https://www.bbcgoodfood.com/recipes/sausage-roll-twists-tomato-dip, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/snow-capped-fairy-cakes
# From https://www.bbcgoodfood.com/recipes/snow-capped-fairy-cakes, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cheesy-leek-bacon-puff
# From https://www.bbcgoodfood.com/recipes/cheesy-leek-bacon-puff, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/asian-slaw
# From https://www.bbcgoodfood.com/recipes/asian-slaw, getting 2 recommended links at depth 7.
# Processing article: https://www.bbcgoodfood.com/recipes/chipotle-chicken-tacos-pineapple-salsa
# From https://www.bbcgoodfood.com/recipes/chipotle-chicken-tacos-pineapple-salsa, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/red-pepper-tomato-salsa
# From https://www.bbcgoodfood.com/recipes/red-pepper-tomato-salsa, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/griddled-flatbreads
# From https://www.bbcgoodfood.com/recipes/griddled-flatbreads, getting 4 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/pea-artichoke-hummus
# From https://www.bbcgoodfood.com/recipes/pea-artichoke-hummus, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/johns-great-guacamole
# From https://www.bbcgoodfood.com/recipes/johns-great-guacamole, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/john-torodes-big-burger
# From https://www.bbcgoodfood.com/recipes/john-torodes-big-burger, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/pineapple-pink-grapefruit-mint-sugar
# From https://www.bbcgoodfood.com/recipes/pineapple-pink-grapefruit-mint-sugar, getting 2 recommended links at depth 1.
# ...
# From https://www.bbcgoodfood.com/recipes/turkey-cobb-salad, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/rainbow-winter-dips-crudites
# From https://www.bbcgoodfood.com/recipes/rainbow-winter-dips-crudites, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/smoky-veggie-nachos
# From https://www.bbcgoodfood.com/recipes/smoky-veggie-nachos, getting 5 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/beef-stroganoff
# From https://www.bbcgoodfood.com/recipes/beef-stroganoff, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/hearty-lamb-stew
# From https://www.bbcgoodfood.com/recipes/hearty-lamb-stew, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/sausage-bean-casserole
# From https://www.bbcgoodfood.com/recipes/sausage-bean-casserole, getting 5 recommended links at depth 1.
# Processing article: https://www.bbcgoodfood.com/recipes/dum-aloo
# From https://www.bbcgoodfood.com/recipes/dum-aloo, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/korean-bibimbap
# From https://www.bbcgoodfood.com/recipes/korean-bibimbap, getting 2 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/black-bean-sauce
# From https://www.bbcgoodfood.com/recipes/black-bean-sauce, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/bokkeumbap
# From https://www.bbcgoodfood.com/recipes/bokkeumbap, getting 4 recommended links at depth 1.
# Processing article: https://www.bbcgoodfood.com/recipes/cardamom-chicken-lime-leaves
# From https://www.bbcgoodfood.com/recipes/cardamom-chicken-lime-leaves, getting 5 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/brie-apple-onion-tart
# From https://www.bbcgoodfood.com/recipes/brie-apple-onion-tart, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/orange-fennel-wild-rice-salad
# From https://www.bbcgoodfood.com/recipes/orange-fennel-wild-rice-salad, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/christmas-tree-garlic-bread
# From https://www.bbcgoodfood.com/recipes/christmas-tree-garlic-bread, getting 4 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/venison-sausage-chestnut-casserole
# From https://www.bbcgoodfood.com/recipes/venison-sausage-chestnut-casserole, getting 2 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/alaskan-yule-log
# From https://www.bbcgoodfood.com/recipes/alaskan-yule-log, getting 5 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/chocolate-sundaes-pear-christmas-pud
# From https://www.bbcgoodfood.com/recipes/chocolate-sundaes-pear-christmas-pud, getting 5 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/sourdough-pancakes
# From https://www.bbcgoodfood.com/recipes/sourdough-pancakes, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/salted-peanut-butter
# From https://www.bbcgoodfood.com/recipes/salted-peanut-butter, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/peanut-butter-cake
# From https://www.bbcgoodfood.com/recipes/peanut-butter-cake, getting 2 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/spiced-duck-breasts-with-sticky-clementine-sauce
# From https://www.bbcgoodfood.com/recipes/spiced-duck-breasts-with-sticky-clementine-sauce, getting 4 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/baked-carrot-sweet-potato-mash
# From https://www.bbcgoodfood.com/recipes/baked-carrot-sweet-potato-mash, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/brussels-sprouts-bacon-chestnuts
# From https://www.bbcgoodfood.com/recipes/brussels-sprouts-bacon-chestnuts, getting 3 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/kol-boregi-potato-red-pepper-spinach-cheese-filo-pie
# From https://www.bbcgoodfood.com/recipes/kol-boregi-potato-red-pepper-spinach-cheese-filo-pie, getting 5 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/lentil-ragu-courgetti
# From https://www.bbcgoodfood.com/recipes/lentil-ragu-courgetti, getting 5 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/zingy-teriyaki-beef-skewers
# From https://www.bbcgoodfood.com/recipes/zingy-teriyaki-beef-skewers, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/supergreen-soup-yogurt-pine-nuts
# From https://www.bbcgoodfood.com/recipes/supergreen-soup-yogurt-pine-nuts, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/gnocchi-courgette-mascarpone-spring-onions
# From https://www.bbcgoodfood.com/recipes/gnocchi-courgette-mascarpone-spring-onions, getting 2 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/lighter-beef-stew-dumplings
# From https://www.bbcgoodfood.com/recipes/lighter-beef-stew-dumplings, getting 4 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/wilted-spring-greens-nut-oil
# From https://www.bbcgoodfood.com/recipes/wilted-spring-greens-nut-oil, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/baked-lemon-sole-lemon-caper-paste
# From https://www.bbcgoodfood.com/recipes/baked-lemon-sole-lemon-caper-paste, getting 4 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/new-potatoes-cheddar-cheese-sauce
# From https://www.bbcgoodfood.com/recipes/new-potatoes-cheddar-cheese-sauce, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/braised-baby-leeks
# From https://www.bbcgoodfood.com/recipes/braised-baby-leeks, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/jacks-pork-cassoulet
# From https://www.bbcgoodfood.com/recipes/jacks-pork-cassoulet, getting 4 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/mustard-stuffed-chicken
# From https://www.bbcgoodfood.com/recipes/mustard-stuffed-chicken, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crushed-olive-oil-potatoes
# From https://www.bbcgoodfood.com/recipes/crushed-olive-oil-potatoes, getting 2 recommended links at depth 3.
# Scraping the main page: Found 17 recipes.
# Processing article: https://www.bbcgoodfood.com/recipes/chicken-meatballs-quinoa-curried-cauliflower
# From https://www.bbcgoodfood.com/recipes/chicken-meatballs-quinoa-curried-cauliflower, getting 5 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/lentil-ragu
# From https://www.bbcgoodfood.com/recipes/lentil-ragu, getting 3 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/mild-chilli-bean-pasta-bake
# From https://www.bbcgoodfood.com/recipes/mild-chilli-bean-pasta-bake, getting 2 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/creamy-pasta-asparagus-peas
# From https://www.bbcgoodfood.com/recipes/creamy-pasta-asparagus-peas, getting 4 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/brie-bruschetta-tomato-herbs-serrano-ham
# From https://www.bbcgoodfood.com/recipes/brie-bruschetta-tomato-herbs-serrano-ham, getting 2 recommended links at depth 1.
# Processing article: https://www.bbcgoodfood.com/recipes/spring-chicken-paella
# From https://www.bbcgoodfood.com/recipes/spring-chicken-paella, getting 4 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/tomato-mint-salad
# From https://www.bbcgoodfood.com/recipes/tomato-mint-salad, getting 2 recommended links at depth 1.
# Processing article: https://www.bbcgoodfood.com/recipes/pesto-crusted-cod-puy-lentils
# From https://www.bbcgoodfood.com/recipes/pesto-crusted-cod-puy-lentils, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/strawberry-white-balsamic-ice-cream
# From https://www.bbcgoodfood.com/recipes/strawberry-white-balsamic-ice-cream, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/goats-cheese-new-potato-tart
# From https://www.bbcgoodfood.com/recipes/goats-cheese-new-potato-tart, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/warm-peaches-basil-honey
# From https://www.bbcgoodfood.com/recipes/warm-peaches-basil-honey, getting 3 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crispy-chicken-asparagus-pie
# From https://www.bbcgoodfood.com/recipes/crispy-chicken-asparagus-pie, getting 3 recommended links at depth 4.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/hot-dressed-carrots-coriander
# From https://www.bbcgoodfood.com/recipes/hot-dressed-carrots-coriander, getting 3 recommended links at depth 5.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/mustard-roasted-beef-fillet
# From https://www.bbcgoodfood.com/recipes/mustard-roasted-beef-fillet, getting 3 recommended links at depth 6.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/perfect-roast-potatoes
# From https://www.bbcgoodfood.com/recipes/perfect-roast-potatoes, getting 3 recommended links at depth 7.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lemony-roast-chicken-couscous
# From https://www.bbcgoodfood.com/recipes/lemony-roast-chicken-couscous, getting 2 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/heirloom-tomato-watermelon-salad
# From https://www.bbcgoodfood.com/recipes/heirloom-tomato-watermelon-salad, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/lamb-rosemary-koftas
# From https://www.bbcgoodfood.com/recipes/lamb-rosemary-koftas, getting 5 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/one-pot-chicken-pilaf
# From https://www.bbcgoodfood.com/recipes/one-pot-chicken-pilaf, getting 3 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/5-day-tagine
# From https://www.bbcgoodfood.com/recipes/5-day-tagine, getting 3 recommended links at depth 1.
# Processing article: https://www.bbcgoodfood.com/recipes/cheesy-tuna-pesto-pasta
# From https://www.bbcgoodfood.com/recipes/cheesy-tuna-pesto-pasta, getting 2 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/one-pot-roast-pork-chops-fennel-potatoes
# From https://www.bbcgoodfood.com/recipes/one-pot-roast-pork-chops-fennel-potatoes, getting 2 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/one-pan-tikka-salmon-jewelled-rice
# From https://www.bbcgoodfood.com/recipes/one-pan-tikka-salmon-jewelled-rice, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/broccoli-fried-onion-garlic
# From https://www.bbcgoodfood.com/recipes/broccoli-fried-onion-garlic, getting 3 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/roast-beef-sirloin-simple-asian-sauce
# From https://www.bbcgoodfood.com/recipes/roast-beef-sirloin-simple-asian-sauce, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/tomato-onion-cucumber-raita
# From https://www.bbcgoodfood.com/recipes/tomato-onion-cucumber-raita, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/bbq-tandoori-style-chicken
# From https://www.bbcgoodfood.com/recipes/bbq-tandoori-style-chicken, getting 5 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/5-day-chicken-kale-pistachio-pesto
# From https://www.bbcgoodfood.com/recipes/5-day-chicken-kale-pistachio-pesto, getting 2 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/veggie-protein-chilli
# From https://www.bbcgoodfood.com/recipes/veggie-protein-chilli, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/instant-berry-banana-slush
# From https://www.bbcgoodfood.com/recipes/instant-berry-banana-slush, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/veggie-thai-red-curry
# From https://www.bbcgoodfood.com/recipes/veggie-thai-red-curry, getting 3 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/avocado-tamari-ginger-dressing
# From https://www.bbcgoodfood.com/recipes/avocado-tamari-ginger-dressing, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/roasted-pepper-halloumi-wraps
# From https://www.bbcgoodfood.com/recipes/roasted-pepper-halloumi-wraps, getting 2 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/prawn-avocado-pasta-salad
# From https://www.bbcgoodfood.com/recipes/prawn-avocado-pasta-salad, getting 2 recommended links at depth 2.
# Processing article: https://www.bbcgoodfood.com/recipes/vegetable-tagine-apricot-quinoa
# From https://www.bbcgoodfood.com/recipes/vegetable-tagine-apricot-quinoa, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/mint-relish-raita
# From https://www.bbcgoodfood.com/recipes/mint-relish-raita, getting 4 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/piri-piri-prawns
# From https://www.bbcgoodfood.com/recipes/piri-piri-prawns, getting 5 recommended links at depth 2.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/turmeric-pilau-golden-onions
# From https://www.bbcgoodfood.com/recipes/turmeric-pilau-golden-onions, getting 4 recommended links at depth 3.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/tikka-style-fish
# From https://www.bbcgoodfood.com/recipes/tikka-style-fish, getting 3 recommended links at depth 4.
# Processing article: https://www.bbcgoodfood.com/recipes/jerk-chicken-mango-bowl
# From https://www.bbcgoodfood.com/recipes/jerk-chicken-mango-bowl, getting 4 recommended links at depth 0.
# Processing article: https://www.bbcgoodfood.com/recipes/tuna-avocado-quinoa-salad
# From https://www.bbcgoodfood.com/recipes/tuna-avocado-quinoa-salad, getting 5 recommended links at depth 0.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/crab-avocado-herby-hollandaise-tarts
# From https://www.bbcgoodfood.com/recipes/crab-avocado-herby-hollandaise-tarts, getting 2 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/halloumi-lemony-lentils-chickpeas-beets
# From https://www.bbcgoodfood.com/recipes/halloumi-lemony-lentils-chickpeas-beets, getting 5 recommended links at depth 1.
# Processing recommended article: https://www.bbcgoodfood.com/recipes/cucumber-elderflower-spritzer
# From https://www.bbcgoodfood.com/recipes/cucumber-elderflower-spritzer, getting 3 recommended links at depth 2.
